# %%
from sqlalchemy import create_engine, inspect
import pandas as pd
import numpy as np
import json
import re
from config import db_password
import time

# %%
engine = create_engine f"sqlite:///{database_}
# Out:
#   File "C:\Users\taher\AppData\Local\Temp/ipykernel_8240/3105003383.py", line 1
#     engine = create_engine f"sqlite:///{database_}
#                                                   ^
# SyntaxError: EOL while scanning string literal

# %%
file_dir = "C://Users/taher/Data Analysis Coursework/Module 8/"

# %%
with open(f'{file_dir}/wikipedia-movies.json',mode='r') as file:
    wiki_movies_raw = json.load(file)

print(len(wiki_movies_raw))
# Out:
# 7311

# %%
wiki_movies_df = pd.DataFrame(wiki_movies_raw)
wiki_movies_df.columns.to_list()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
#  'Cover artist',
#  'Series',
#  'Set in',
#  'Adaptation by',
#  'Suggested by',
#  'Biographical data',
#  'Born',
#  'Died',
#  'Resting place',
#  'Occupation',
#  'Years active',
#  'Spouse(s)',
#  'Children',
#  'Parent(s)',
#  'Genres',
#  'Instruments',
#  'Labels',
#  'Website',
#  'Traditional',
#  'Mandarin',
#  'Type',
#  'Industry',
#  'Fate',
#  'Founded',
#  'Founder',
#  'Headquarters',
#  'Parent',
#  'Released',
#  'Recorded',
#  'Venue',
#  'Length',
#  'Label',
#  'Director',
#  'Producer',
#  'Area',
#  'Coordinates',
#  'Status',
#  'Opening date',
#  'Closing date',
#  'Replaced',
#  'Replaced by',
#  'Name',
#  'Attraction type',
#  'Music',
#  'Duration',
#  'Simplified Chinese',
#  'Traditional Chinese',
#  'Hanyu Pinyin',
#  'Literal meaning',
#  'Transcriptions',
#  'Bopomofo',
#  'Gwoyeu Romatzyh',
#  'Wade–Giles',
#  'IPA',
#  'Yale Romanization',
#  'Jyutping',
#  'Hokkien POJ',
#  'Animation by',
#  'Color process',
#  'Engine(s)',
#  'Genre(s)',
#  'Actor control',
#  'Production company',
#  'Release(s)',
#  'Format(s)',
#  'Simplified',
#  'Characters',
#  'Date premiered',
#  'Place premiered',
#  'Setting',
#  'Original language',
#  'Subject',
#  'Published',
#  'Dewey Decimal',
#  'Text',
#  'Illustrator',
#  'Original title',
#  'Published in English',
#  'French',
#  'Developed by',
#  'Ending theme',
#  'No. of seasons',
#  'Nationality',
#  'Portrayed by',
#  'Alias',
#  'Species',
#  'Gender',
#  'Family',
#  'Alma mater',
#  'Camera setup',
#  'Novel(s)',
#  'Comics',
#  'Film(s)',
#  'Screen story by',
#  'Hangul',
#  'Revised Romanization',
#  'McCune–Reischauer',
#  'Developer(s)',
#  'Publisher(s)',
#  'Designer(s)',
#  'Programmer(s)',
#  'Artist(s)',
#  'Writer(s)',
#  'Engine',
#  'Platform(s)',
#  'Release',
#  'Mode(s)',
#  'Original work',
#  'Television series',
#  'Japanese',
#  'Hepburn',
#  'Literally',
#  'Cantonese',
#  'Full name',
#  'Height',
#  'Seasons',
#  'Chinese',
#  'Other names',
#  'Relatives',
#  'Yiddish',
#  'Formerly',
#  'Key people',
#  'Total assets',
#  'Owner',
#  'Number of employees',
#  'Divisions',
#  'Subsidiaries',
#  'Arabic',
#  'Romanized',
#  'Predecessor',
#  'Founders',
#  'Area served',
#  'Products',
#  'Services',
#  'Russian',
#  'Hebrew',
#  'Revenue',
#  'Operating income',
#  'Polish']

# %%
kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv',low_memory = False)
ratings = pd.read_csv(f'{file_dir}ratings.csv')

# %%
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                and 'imdb_link' in movie
                and 'No. of episodes' not in movie]

len(wiki_movies)
# Out:
# 7076

# %%
def clean_movie(movie):
    movie = dict(movie)
    alt_titles = {}
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles

    def change_column_name(old_name,new_name):
    
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Country of origin', 'Country')
    change_column_name('Directed by', 'Director')
    change_column_name('Distributed by', 'Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Length', 'Running time')
    change_column_name('Original release', 'Release date')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release Date')
    change_column_name('Release Date', 'Release date')
    change_column_name('Screen story by', 'Writer(s)')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Story by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Written by', 'Writer(s)')
    
    return movie

# %%
clean_movies = [clean_movie(movie) for movie in wiki_movies]
wiki_movies_df = pd.DataFrame(clean_movies)

# %%
wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')


wiki_movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7071    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7072     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7073  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7074  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7075  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1     https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2     https://www.imdb.com/title/tt0099005/                      Air America
# 3     https://www.imdb.com/title/tt0099012/                            Alice
# 4     https://www.imdb.com/title/tt0099018/                  Almost an Angel
# ...                                     ...                              ...
# 7071  https://www.imdb.com/title/tt1255919/                  Holmes & Watson
# 7072  https://www.imdb.com/title/tt6266538/                             Vice
# 7073  https://www.imdb.com/title/tt4669788/              On the Basis of Sex
# 7074  https://www.imdb.com/title/tt7137380/                        Destroyer
# 7075  https://www.imdb.com/title/tt9495224/                     Bandersnatch
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
# 7072                                                NaN
# 7073                                                NaN
# 7074                                                NaN
# 7075                                                NaN
#
#                                                Starring         Narrated by  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  Andrew "Dice" Clay
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...                 NaN
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...                 NaN
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...                 NaN
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]                 NaN
# ...                                                 ...                 ...
# 7071  [Will Ferrell, John C. Reilly, Rebecca Hall, R...                 NaN
# 7072  [Christian Bale, Amy Adams, Steve Carell, Sam ...                 NaN
# 7073  [Felicity Jones, Armie Hammer, Justin Theroux,...                 NaN
# 7074  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...                 NaN
# 7075  [Fionn Whitehead, Will Poulter, Craig Parkinso...                 NaN
#
#                      Cinematography  \
# 0                       Oliver Wood
# 1                      Mark Plummer
# 2                     Roger Deakins
# 3                    Carlo Di Palma
# 4                      Russell Boyd
# ...                             ...
# 7071                    Oliver Wood
# 7072                   Greig Fraser
# 7073                  Michael Grady
# 7074                 Julie Kirkwood
# 7075  [Aaron Morton, Jake Polonsky]
#
#                                            Release date  \
# 0                     [July 11, 1990, (, 1990-07-11, )]
# 1     [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2                   [August 10, 1990, (, 1990-08-10, )]
# 3                 [December 25, 1990, (, 1990-12-25, )]
# 4                                     December 19, 1990
# ...                                                 ...
# 7071  [December 25, 2018, (, 2018-12-25, ), (United ...
# 7072  [December 11, 2018, (, 2018-12-11, ), (, Samue...
# 7073  [November 8, 2018, (, 2018-11-08, ), (, AFI Fe...
# 7074  [August 31, 2018, (, 2018-08-31, ), (, Telluri...
# 7075               [28 December 2018, (, 2018-12-28, )]
#
#                                Running time  ... Created by Preceded by  \
# 0                               102 minutes  ...        NaN         NaN
# 1                               114 minutes  ...        NaN         NaN
# 2                               113 minutes  ...        NaN         NaN
# 3                               106 minutes  ...        NaN         NaN
# 4                                95 minutes  ...        NaN         NaN
# ...                                     ...  ...        ...         ...
# 7071                             90 minutes  ...        NaN         NaN
# 7072                            132 minutes  ...        NaN         NaN
# 7073                            120 minutes  ...        NaN         NaN
# 7074                            123 minutes  ...        NaN         NaN
# 7075  Variable; 90 minutes for default path  ...        NaN         NaN
#
#      Suggested by alt_titles Recorded Venue Label Animation by Color process  \
# 0             NaN        NaN      NaN   NaN   NaN          NaN           NaN
# 1             NaN        NaN      NaN   NaN   NaN          NaN           NaN
# 2             NaN        NaN      NaN   NaN   NaN          NaN           NaN
# 3             NaN        NaN      NaN   NaN   NaN          NaN           NaN
# 4             NaN        NaN      NaN   NaN   NaN          NaN           NaN
# ...           ...        ...      ...   ...   ...          ...           ...
# 7071          NaN        NaN      NaN   NaN   NaN          NaN           NaN
# 7072          NaN        NaN      NaN   NaN   NaN          NaN           NaN
# 7073          NaN        NaN      NaN   NaN   NaN          NaN           NaN
# 7074          NaN        NaN      NaN   NaN   NaN          NaN           NaN
# 7075          NaN        NaN      NaN   NaN   NaN          NaN           NaN
#
#         imdb_id
# 0     tt0098987
# 1     tt0098994
# 2     tt0099005
# 3     tt0099012
# 4     tt0099018
# ...         ...
# 7071  tt1255919
# 7072  tt6266538
# 7073  tt4669788
# 7074  tt7137380
# 7075  tt9495224
#
# [7076 rows x 40 columns]

# %%
wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < (len(wiki_movies_df)* 0.9)]
wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]

wiki_movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7071    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7072     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7073  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7074  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7075  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1     https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2     https://www.imdb.com/title/tt0099005/                      Air America
# 3     https://www.imdb.com/title/tt0099012/                            Alice
# 4     https://www.imdb.com/title/tt0099018/                  Almost an Angel
# ...                                     ...                              ...
# 7071  https://www.imdb.com/title/tt1255919/                  Holmes & Watson
# 7072  https://www.imdb.com/title/tt6266538/                             Vice
# 7073  https://www.imdb.com/title/tt4669788/              On the Basis of Sex
# 7074  https://www.imdb.com/title/tt7137380/                        Destroyer
# 7075  https://www.imdb.com/title/tt9495224/                     Bandersnatch
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
# 7072                                                NaN
# 7073                                                NaN
# 7074                                                NaN
# 7075                                                NaN
#
#                                                Starring  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]
# ...                                                 ...
# 7071  [Will Ferrell, John C. Reilly, Rebecca Hall, R...
# 7072  [Christian Bale, Amy Adams, Steve Carell, Sam ...
# 7073  [Felicity Jones, Armie Hammer, Justin Theroux,...
# 7074  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...
# 7075  [Fionn Whitehead, Will Poulter, Craig Parkinso...
#
#                      Cinematography  \
# 0                       Oliver Wood
# 1                      Mark Plummer
# 2                     Roger Deakins
# 3                    Carlo Di Palma
# 4                      Russell Boyd
# ...                             ...
# 7071                    Oliver Wood
# 7072                   Greig Fraser
# 7073                  Michael Grady
# 7074                 Julie Kirkwood
# 7075  [Aaron Morton, Jake Polonsky]
#
#                                            Release date  \
# 0                     [July 11, 1990, (, 1990-07-11, )]
# 1     [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2                   [August 10, 1990, (, 1990-08-10, )]
# 3                 [December 25, 1990, (, 1990-12-25, )]
# 4                                     December 19, 1990
# ...                                                 ...
# 7071  [December 25, 2018, (, 2018-12-25, ), (United ...
# 7072  [December 11, 2018, (, 2018-12-11, ), (, Samue...
# 7073  [November 8, 2018, (, 2018-11-08, ), (, AFI Fe...
# 7074  [August 31, 2018, (, 2018-08-31, ), (, Telluri...
# 7075               [28 December 2018, (, 2018-12-28, )]
#
#                                Running time         Country  ...       Budget  \
# 0                               102 minutes   United States  ...  $20 million
# 1                               114 minutes   United States  ...   $6 million
# 2                               113 minutes   United States  ...  $35 million
# 3                               106 minutes   United States  ...  $12 million
# 4                                95 minutes              US  ...  $25 million
# ...                                     ...             ...  ...          ...
# 7071                             90 minutes   United States  ...  $42 million
# 7072                            132 minutes   United States  ...  $60 million
# 7073                            120 minutes   United States  ...  $20 million
# 7074                            123 minutes   United States  ...   $9 million
# 7075  Variable; 90 minutes for default path  United Kingdom  ...          NaN
#
#             Box office            Director              Distributor  \
# 0        $21.4 million        Renny Harlin         20th Century Fox
# 1         $2.7 million         James Foley          Avenue Pictures
# 2          $57,718,089  Roger Spottiswoode         TriStar Pictures
# 3           $7,331,647         Woody Allen           Orion Pictures
# 4     $6,939,946 (USA)        John Cornell       Paramount Pictures
# ...                ...                 ...                      ...
# 7071     $41.9 million          Etan Cohen  Sony Pictures Releasing
# 7072     $76.1 million          Adam McKay         Mirror Releasing
# 7073     $38.4 million          Mimi Leder           Focus Features
# 7074      $5.5 million        Karyn Kusama         Mirror Releasing
# 7075               NaN         David Slade                  Netflix
#
#                            Editor(s)              Composer(s)  \
# 0                    Michael Tronick  [Cliff Eidelman, Yello]
# 1                    Howard E. Smith            Maurice Jarre
# 2     [John Bloom, Lois Freeman-Fox]            Charles Gross
# 3                     Susan E. Morse                      NaN
# 4                       David Stiven            Maurice Jarre
# ...                              ...                      ...
# 7071                  Dean Zimmerman        Mark Mothersbaugh
# 7072                     Hank Corwin         Nicholas Britell
# 7073                 Michelle Tesoro            Mychael Danna
# 7074                   Plummy Tucker         Theodore Shapiro
# 7075                     Tony Kearns           Brian Reitzell
#
#                                             Producer(s)  \
# 0                            [Steve Perry, Joel Silver]
# 1                           [Ric Kidney, Robert Redlin]
# 2                                        Daniel Melnick
# 3                                       Robert Greenhut
# 4                                          John Cornell
# ...                                                 ...
# 7071  [Will Ferrell, Adam McKay, Jimmy Miller, Clayt...
# 7072  [Brad Pitt, Dede Gardner, Jeremy Kleiner, Kevi...
# 7073                                     Robert W. Cort
# 7074             [Fred Berger, Phil Hay, Matt Manfredi]
# 7075                                     Russell McLean
#
#                                   Production company(s)  \
# 0                                       Silver Pictures
# 1                                       Avenue Pictures
# 2                 [Carolco Pictures, IndieProd Company]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Columbia Pictures, Gary Sanchez Productions, ...
# 7072  [Plan B Entertainment, Gary Sanchez Production...
# 7073  [Focus Features, [1], Participant Media, [1], ...
# 7074  [30West, Automatik Entertainment, Annapurna Pi...
# 7075                       [House of Tomorrow, Netflix]
#
#                          Writer(s)    imdb_id
# 0      [David Arnott, James Cappe]  tt0098987
# 1     [James Foley, Robert Redlin]  tt0098994
# 2       [John Eskow, Richard Rush]  tt0099005
# 3                      Woody Allen  tt0099012
# 4                       Paul Hogan  tt0099018
# ...                            ...        ...
# 7071                    Etan Cohen  tt1255919
# 7072                    Adam McKay  tt6266538
# 7073             Daniel Stiepleman  tt4669788
# 7074     [Phil Hay, Matt Manfredi]  tt7137380
# 7075               Charlie Brooker  tt9495224
#
# [7076 rows x 21 columns]

# %%
box_office = wiki_movies_df['Box office'].dropna()
box_office = box_office.apply(lambda x:' '.join(x) if type(x) == list else x)

# %%
form_one = r'\$\s*\d+\.?\d*\s*[mb]illi?on'
form_two = r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)'
box_office = box_office.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)
box_office.str.extract(f'({form_one}|{form_two})')
# Out:
#                   0
# 0     $21.4 million
# 1      $2.7 million
# 2       $57,718,089
# 3        $7,331,647
# 4        $6,939,946
# ...             ...
# 7070  $19.4 million
# 7071  $41.9 million
# 7072  $76.1 million
# 7073  $38.4 million
# 7074   $5.5 million
#
# [5517 rows x 1 columns]

# %%
def parse_dollars(s):
    # if s is not a string, return NaN
    if type(s) != str:
        return np.nan

    # if input is of the form $###.# million
    if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.IGNORECASE):

        # remove dollar sign and " million"
        s = re.sub('\$|\s|[a-zA-Z]','', s)

        # convert to float and multiply by a million
        value = float(s) * 10**6

        # return value
        return value

    # if input is of the form $###.# billion
    elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):

        # remove dollar sign and " billion"
        s = re.sub('\$|\s|[a-zA-Z]','', s)

        # convert to float and multiply by a billion
        value = float(s) * 10**9

        # return value
        return value

    # if input is of the form $###,###,###
    elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)', s, flags=re.IGNORECASE):

        # remove dollar sign and commas
        s = re.sub('\$|,','', s)

        # convert to float
        value = float(s)

        # return value
        return value

    # otherwise, return NaN
    else:
        return np.nan

# %%
wiki_movies_df['box_office'] = box_office.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)
wiki_movies_df.drop('Box office', axis=1, inplace=True)
# Out:
# C:\Users\taher\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\taher\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
budget = wiki_movies_df['Budget'].dropna()
budget = budget.map(lambda x: ' '.join(x) if type(x) == list else x)
budget = budget.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)
budget = budget.str.replace(r'\[\d+\]\s*', '')

matches_form_one = budget.str.contains(form_one, flags=re.IGNORECASE, na=False)
matches_form_two = budget.str.contains(form_two, flags=re.IGNORECASE, na=False)
budget[~matches_form_one & ~matches_form_two]
# Out:
# C:\Users\taher\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 620     60 million Norwegian Kroner
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3418                        $218.32
# 3802                   £4.2 million
# 3906                            N/A
# 3959                    760,000 USD
# 4470                       19 crore
# 4641                    £17 million
# 5424                            N/A
# 5447                     £4 million
# 5671                    €14 million
# 5687                   $ dead link]
# 6385                  £ 12 million
# 6593                     £3 million
# 6821                  £12.9 million
# 6843                      3.5 crore
# 6895                        919,000
# 7070                   €4.3 million
# Name: Budget, dtype: object

# %%
wiki_movies_df['budget'] = budget.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)
wiki_movies_df.drop('Budget', axis=1, inplace=True)
wiki_movies_df
# Out:
# C:\Users\taher\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7071    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7072     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7073  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7074  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7075  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1     https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2     https://www.imdb.com/title/tt0099005/                      Air America
# 3     https://www.imdb.com/title/tt0099012/                            Alice
# 4     https://www.imdb.com/title/tt0099018/                  Almost an Angel
# ...                                     ...                              ...
# 7071  https://www.imdb.com/title/tt1255919/                  Holmes & Watson
# 7072  https://www.imdb.com/title/tt6266538/                             Vice
# 7073  https://www.imdb.com/title/tt4669788/              On the Basis of Sex
# 7074  https://www.imdb.com/title/tt7137380/                        Destroyer
# 7075  https://www.imdb.com/title/tt9495224/                     Bandersnatch
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Sherlock Holmes, and, Dr. Watson, by, Sir Art...
# 7072                                                NaN
# 7073                                                NaN
# 7074                                                NaN
# 7075                                                NaN
#
#                                                Starring  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]
# ...                                                 ...
# 7071  [Will Ferrell, John C. Reilly, Rebecca Hall, R...
# 7072  [Christian Bale, Amy Adams, Steve Carell, Sam ...
# 7073  [Felicity Jones, Armie Hammer, Justin Theroux,...
# 7074  [Nicole Kidman, Sebastian Stan, Toby Kebbell, ...
# 7075  [Fionn Whitehead, Will Poulter, Craig Parkinso...
#
#                      Cinematography  \
# 0                       Oliver Wood
# 1                      Mark Plummer
# 2                     Roger Deakins
# 3                    Carlo Di Palma
# 4                      Russell Boyd
# ...                             ...
# 7071                    Oliver Wood
# 7072                   Greig Fraser
# 7073                  Michael Grady
# 7074                 Julie Kirkwood
# 7075  [Aaron Morton, Jake Polonsky]
#
#                                            Release date  \
# 0                     [July 11, 1990, (, 1990-07-11, )]
# 1     [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2                   [August 10, 1990, (, 1990-08-10, )]
# 3                 [December 25, 1990, (, 1990-12-25, )]
# 4                                     December 19, 1990
# ...                                                 ...
# 7071  [December 25, 2018, (, 2018-12-25, ), (United ...
# 7072  [December 11, 2018, (, 2018-12-11, ), (, Samue...
# 7073  [November 8, 2018, (, 2018-11-08, ), (, AFI Fe...
# 7074  [August 31, 2018, (, 2018-08-31, ), (, Telluri...
# 7075               [28 December 2018, (, 2018-12-28, )]
#
#                                Running time         Country  ...  \
# 0                               102 minutes   United States  ...
# 1                               114 minutes   United States  ...
# 2                               113 minutes   United States  ...
# 3                               106 minutes   United States  ...
# 4                                95 minutes              US  ...
# ...                                     ...             ...  ...
# 7071                             90 minutes   United States  ...
# 7072                            132 minutes   United States  ...
# 7073                            120 minutes   United States  ...
# 7074                            123 minutes   United States  ...
# 7075  Variable; 90 minutes for default path  United Kingdom  ...
#
#                 Director              Distributor  \
# 0           Renny Harlin         20th Century Fox
# 1            James Foley          Avenue Pictures
# 2     Roger Spottiswoode         TriStar Pictures
# 3            Woody Allen           Orion Pictures
# 4           John Cornell       Paramount Pictures
# ...                  ...                      ...
# 7071          Etan Cohen  Sony Pictures Releasing
# 7072          Adam McKay         Mirror Releasing
# 7073          Mimi Leder           Focus Features
# 7074        Karyn Kusama         Mirror Releasing
# 7075         David Slade                  Netflix
#
#                            Editor(s)              Composer(s)  \
# 0                    Michael Tronick  [Cliff Eidelman, Yello]
# 1                    Howard E. Smith            Maurice Jarre
# 2     [John Bloom, Lois Freeman-Fox]            Charles Gross
# 3                     Susan E. Morse                      NaN
# 4                       David Stiven            Maurice Jarre
# ...                              ...                      ...
# 7071                  Dean Zimmerman        Mark Mothersbaugh
# 7072                     Hank Corwin         Nicholas Britell
# 7073                 Michelle Tesoro            Mychael Danna
# 7074                   Plummy Tucker         Theodore Shapiro
# 7075                     Tony Kearns           Brian Reitzell
#
#                                             Producer(s)  \
# 0                            [Steve Perry, Joel Silver]
# 1                           [Ric Kidney, Robert Redlin]
# 2                                        Daniel Melnick
# 3                                       Robert Greenhut
# 4                                          John Cornell
# ...                                                 ...
# 7071  [Will Ferrell, Adam McKay, Jimmy Miller, Clayt...
# 7072  [Brad Pitt, Dede Gardner, Jeremy Kleiner, Kevi...
# 7073                                     Robert W. Cort
# 7074             [Fred Berger, Phil Hay, Matt Manfredi]
# 7075                                     Russell McLean
#
#                                   Production company(s)  \
# 0                                       Silver Pictures
# 1                                       Avenue Pictures
# 2                 [Carolco Pictures, IndieProd Company]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7071  [Columbia Pictures, Gary Sanchez Productions, ...
# 7072  [Plan B Entertainment, Gary Sanchez Production...
# 7073  [Focus Features, [1], Participant Media, [1], ...
# 7074  [30West, Automatik Entertainment, Annapurna Pi...
# 7075                       [House of Tomorrow, Netflix]
#
#                          Writer(s)    imdb_id  box_office      budget
# 0      [David Arnott, James Cappe]  tt0098987  21400000.0  20000000.0
# 1     [James Foley, Robert Redlin]  tt0098994   2700000.0   6000000.0
# 2       [John Eskow, Richard Rush]  tt0099005  57718089.0  35000000.0
# 3                      Woody Allen  tt0099012   7331647.0  12000000.0
# 4                       Paul Hogan  tt0099018   6939946.0  25000000.0
# ...                            ...        ...         ...         ...
# 7071                    Etan Cohen  tt1255919  41900000.0  42000000.0
# 7072                    Adam McKay  tt6266538  76100000.0  60000000.0
# 7073             Daniel Stiepleman  tt4669788  38400000.0  20000000.0
# 7074     [Phil Hay, Matt Manfredi]  tt7137380   5500000.0   9000000.0
# 7075               Charlie Brooker  tt9495224         NaN         NaN
#
# [7076 rows x 21 columns]

# %%
release_date = wiki_movies_df['Release date'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)
date_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s[123]?\d,\s\d{4}'
date_form_two = r'\d{4}.[01]\d.[0123]\d'
date_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
date_form_four = r'\d{4}'

wiki_movies_df['release_date'] = pd.to_datetime(release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)
# Out:
# C:\Users\taher\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
running_time = wiki_movies_df['Running time'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)
running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE, na=False).sum()
running_time[running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE, na=False) != True]
running_time_extract = running_time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d+)\s*m')
running_time_extract = running_time_extract.apply(lambda x: pd.to_numeric(x, errors='coerce')).fillna(0)
wiki_movies_df['running_time'] = running_time_extract.apply(lambda x: x[0]*60 + x[1] if x[2] == 0 else x[2], axis=1)
wiki_movies_df.drop('Running time', axis=1, inplace=True)
# Out:
# C:\Users\taher\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\taher\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
kaggle_metadata[~kaggle_metadata['adult'].isin(['True','False'])]
kaggle_metadata = kaggle_metadata[kaggle_metadata['adult'] == 'False'].drop('adult',axis='columns')

# %%
kaggle_metadata['video'] = kaggle_metadata['video'] == 'True'
kaggle_metadata['budget'] = kaggle_metadata['budget'].astype(int)
kaggle_metadata['id'] = pd.to_numeric(kaggle_metadata['id'], errors='raise')
kaggle_metadata['popularity'] = pd.to_numeric(kaggle_metadata['popularity'], errors='raise')
kaggle_metadata['release_date'] = pd.to_datetime(kaggle_metadata['release_date'])

ratings.info(null_counts=True)
ratings['timestamp'] = pd.to_datetime(ratings['timestamp'], unit='s')
pd.options.display.float_format = '{:20,.2f}'.format
ratings['rating'].plot(kind='hist')
ratings['rating'].describe()
# Out:
# C:\Users\taher\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: null_counts is deprecated. Use show_counts instead
#   import sys
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26024289 entries, 0 to 26024288
# Data columns (total 4 columns):
#  #   Column     Non-Null Count     Dtype
# ---  ------     --------------     -----
#  0   userId     26024289 non-null  int64
#  1   movieId    26024289 non-null  int64
#  2   rating     26024289 non-null  float64
#  3   timestamp  26024289 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 794.2 MB
# count          26,024,289.00
# mean                    3.53
# std                     1.07
# min                     0.50
# 25%                     3.00
# 50%                     3.50
# 75%                     4.00
# max                     5.00
# Name: rating, dtype: float64

# %%
movies_df = pd.merge(wiki_movies_df, kaggle_metadata, on='imdb_id', suffixes=['_wiki','_kaggle'])
movies_df[['title_wiki','title_kaggle']]
movies_df[movies_df['title_wiki'] != movies_df['title_kaggle']][['title_wiki','title_kaggle']]
movies_df[(movies_df['title_kaggle'] == '') | (movies_df['title_kaggle'].isnull())]
# Out:
# Empty DataFrame
# Columns: [url, year, imdb_link, title_wiki, Based on, Starring, Cinematography, Release date, Country, Language, Director, Distributor, Editor(s), Composer(s), Producer(s), Production company(s), Writer(s), imdb_id, box_office, budget_wiki, release_date_wiki, running_time, belongs_to_collection, budget_kaggle, genres, homepage, id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date_kaggle, revenue, runtime, spoken_languages, status, tagline, title_kaggle, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 44 columns]

# %%
movies_df.fillna(0).plot(x='running_time', y='runtime', kind='scatter')
# Out:
# <AxesSubplot:xlabel='running_time', ylabel='runtime'>

# %%
movies_df.fillna(0).plot(x='budget_wiki',y='budget_kaggle', kind='scatter')
# Out:
# <AxesSubplot:xlabel='budget_wiki', ylabel='budget_kaggle'>

# %%
movies_df.fillna(0).plot(x='box_office', y='revenue', kind='scatter')
# Out:
# <AxesSubplot:xlabel='box_office', ylabel='revenue'>

# %%
movies_df[['release_date_wiki','release_date_kaggle']].plot(x='release_date_wiki', y='release_date_kaggle', style='.')
# Out:
# <AxesSubplot:xlabel='release_date_wiki'>

# %%
movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')]
# Out:
#                                             url  year  \
# 3633  https://en.wikipedia.org/wiki/The_Holiday  2006
#
#                                    imdb_link   title_wiki Based on  \
# 3633  https://www.imdb.com/title/tt00457939/  The Holiday      NaN
#
#                                                Starring Cinematography  \
# 3633  [Kate Winslet, Cameron Diaz, Jude Law, Jack Bl...    Dean Cundey
#
#                               Release date        Country Language  ...  \
# 3633  [December 8, 2006, (, 2006-12-08, )]  United States  English  ...
#
#      release_date_kaggle              revenue              runtime  \
# 3633          1953-08-28        30,500,000.00               118.00
#
#                               spoken_languages    status  \
# 3633  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 3633  Pouring out of impassioned pages...brawling th...
#
#                title_kaggle  video         vote_average           vote_count
# 3633  From Here to Eternity  False                 7.20               137.00
#
# [1 rows x 44 columns]

# %%
movies_df = movies_df.drop(movies_df[(movies_df['release_date_wiki'] > '1996-01-01') & (movies_df['release_date_kaggle'] < '1965-01-01')].index)
movies_df[movies_df['release_date_wiki'].isnull()]
# Out:
#                                                     url  year  \
# 1021  https://en.wikipedia.org/wiki/Black_Scorpion_(...  1995
# 1074    https://en.wikipedia.org/wiki/Flirt_(1995_film)  1995
# 1134  https://en.wikipedia.org/wiki/Let_It_Be_Me_(19...  1995
# 1580  https://en.wikipedia.org/wiki/A_Brooklyn_State...  1997
# 1649      https://en.wikipedia.org/wiki/Highball_(film)  1997
# 1793        https://en.wikipedia.org/wiki/Velocity_Trap  1997
# 2406  https://en.wikipedia.org/wiki/The_Visit_(2000_...  2000
# 2811   https://en.wikipedia.org/wiki/Stevie_(2002_film)  2002
# 3200  https://en.wikipedia.org/wiki/Return_to_Sender...  2004
# 3677  https://en.wikipedia.org/wiki/Live_Free_or_Die...  2006
# 5002  https://en.wikipedia.org/wiki/For_the_Love_of_...  2012
#
#                                   imdb_link                title_wiki  \
# 1021  https://www.imdb.com/title/tt0112519/            Black Scorpion
# 1074  https://www.imdb.com/title/tt0113080/                     Flirt
# 1134  https://www.imdb.com/title/tt0113638/              Let It Be Me
# 1580  https://www.imdb.com/title/tt0118782/  A Brooklyn State of Mind
# 1649  https://www.imdb.com/title/tt0119291/                  Highball
# 1793  https://www.imdb.com/title/tt0120435/             Velocity Trap
# 2406  https://www.imdb.com/title/tt0199129/                 The Visit
# 2811  https://www.imdb.com/title/tt0334416/                    Stevie
# 3200  https://www.imdb.com/title/tt0396190/          Return to Sender
# 3677  https://www.imdb.com/title/tt0432318/          Live Free or Die
# 5002  https://www.imdb.com/title/tt1730294/     For the Love of Money
#
#      Based on                                           Starring  \
# 1021      NaN     [Joan Severance, Bruce Abbott, Garrett Morris]
# 1074      NaN            [Bill Sage, Dwight Ewell, Miho Nikaido]
# 1134      NaN                                                NaN
# 1580      NaN                                                NaN
# 1649      NaN  [Justine Bateman, Peter Bogdanovich, Chris Eig...
# 1793      NaN       [Olivier Gruner, Alicia Coppola, Ken Olandt]
# 2406      NaN  [Hill Harper, Billy Dee Williams, Obba Babatun...
# 2811      NaN                                                NaN
# 3200      NaN         [Aidan Quinn, Connie Nielsen, Mark Holton]
# 3677      NaN  [Aaron Stanford, Paul Schneider, Ebon Moss-Bac...
# 5002      NaN  [Yehuda Levi, Edward Furlong, James Caan, Jeff...
#
#                                   Cinematography Release date  \
# 1021                                Geoff George          NaN
# 1074                             Michael Spiller          NaN
# 1134                           Miroslav Ondrícek          NaN
# 1580                                  Ken Kelsch          NaN
# 1649                            Steven Bernstein          NaN
# 1793                          Philip D. Schwartz          NaN
# 2406                           John L. Demps Jr.          NaN
# 2811  [Dana Kupper, Gordon Quinn, Peter Gilbert]          NaN
# 3200                                         NaN          NaN
# 3677                                         NaN          NaN
# 5002                              Andrzej Sekuła          NaN
#
#                                    Country        Language  ...  \
# 1021                         United States             NaN  ...
# 1074  [United States, Germany, Japan, [1]]             NaN  ...
# 1134                                   NaN             NaN  ...
# 1580                                   NaN             NaN  ...
# 1649                         United States         English  ...
# 1793                         United States             NaN  ...
# 2406                                   NaN         English  ...
# 2811                         United States         English  ...
# 3200                    [Denmark, USA, UK]             NaN  ...
# 3677                         United States         English  ...
# 5002                         United States  English/Hebrew  ...
#
#      release_date_kaggle              revenue              runtime  \
# 1021          1995-08-22                 0.00                92.00
# 1074          1995-09-14                 0.00                85.00
# 1134          1995-11-17                 0.00                95.00
# 1580          1998-01-01                 0.00                89.00
# 1649          1997-01-01                 0.00               110.00
# 1793          1999-02-22                 0.00                86.00
# 2406          2000-01-01                 0.00               107.00
# 2811          2002-09-09            97,000.00               140.00
# 3200          2004-09-17                 0.00               109.00
# 3677          2006-03-11                 0.00                89.00
# 5002          2012-06-08                 0.00                93.00
#
#                                        spoken_languages    status  \
# 1021           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1074  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1134                                                 []  Released
# 1580           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1649           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1793           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2406  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...   Rumored
# 2811                                                 []       NaN
# 3200           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3677           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5002  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                                 tagline  \
# 1021                         Justice has a nasty sting.
# 1074                                                NaN
# 1134                                                NaN
# 1580                                                NaN
# 1649                                                NaN
# 1793                        Crime at the Speed of Light
# 2406                                                NaN
# 2811                                                NaN
# 3200  How can you save someone, who won't save herself?
# 3677                                                NaN
# 5002     For the love of money is the root of all evil.
#
#                   title_kaggle  video         vote_average  \
# 1021            Black Scorpion  False                 6.10
# 1074                     Flirt  False                 7.50
# 1134              Let It Be Me  False                 8.00
# 1580  A Brooklyn State of Mind  False                 5.00
# 1649                  Highball  False                 4.50
# 1793             Velocity Trap  False                 4.70
# 2406                 The Visit  False                 0.00
# 2811                    Stevie  False                 6.70
# 3200          Return to Sender  False                 5.90
# 3677          Live Free or Die  False                 5.50
# 5002     For the Love of Money  False                 5.60
#
#                vote_count
# 1021                 7.00
# 1074                 4.00
# 1134                 2.00
# 1580                 1.00
# 1649                 4.00
# 1793                 6.00
# 2406                 0.00
# 2811                13.00
# 3200                13.00
# 3677                 8.00
# 5002                 9.00
#
# [11 rows x 44 columns]

# %%
movies_df['Language'].value_counts()
movies_df['Language'].apply(lambda x: tuple(x) if type(x) == list else x).value_counts(dropna=False)
movies_df['original_language'].value_counts(dropna=False)
# Out:
# en    6026
# fr      16
# es      10
# it       8
# de       6
# ja       4
# pt       4
# zh       4
# da       2
# hi       2
# sv       1
# ko       1
# ab       1
# tr       1
# he       1
# ar       1
# cn       1
# ru       1
# Name: original_language, dtype: int64

# %%
movies_df[['Production company(s)','production_companies']]
# Out:
#                                   Production company(s)  \
# 0                                       Silver Pictures
# 1                                       Avenue Pictures
# 2                 [Carolco Pictures, IndieProd Company]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6086                           [Fabula, Komplizen Film]
# 6087                           Ball & Chain Productions
# 6088          [Arte France Cinéma, Why Not Productions]
# 6089  [Film Science, Rough House Pictures, Syncopate...
# 6090         [HanWay Films, Little Punk, See-Saw Films]
#
#                                    production_companies
# 0     [{'name': 'Twentieth Century Fox Film Corporat...
# 1     [{'name': 'Avenue Pictures Productions', 'id':...
# 2     [{'name': 'IndieProd Company Productions', 'id...
# 3                [{'name': 'Orion Pictures', 'id': 41}]
# 4             [{'name': 'Paramount Pictures', 'id': 4}]
# ...                                                 ...
# 6086  [{'name': 'Komplizen Film', 'id': 1618}, {'nam...
# 6087  [{'name': 'Ball & Chain Productions', 'id': 74...
# 6088  [{'name': 'ARTE France Cinéma', 'id': 94}, {'n...
# 6089  [{'name': 'Film Science', 'id': 1976}, {'name'...
# 6090  [{'name': 'HanWay Films', 'id': 2395}, {'name'...
#
# [6090 rows x 2 columns]

# %%
def fill_missing_kaggle_data(df, kaggle_column, wiki_column):
    df[kaggle_column] = df.apply(
        lambda row: row[wiki_column] if row[kaggle_column] == 0 else row[kaggle_column]
        , axis=1)
    df.drop(columns=wiki_column, inplace=True)

# %%
fill_missing_kaggle_data(movies_df, 'runtime', 'running_time')
fill_missing_kaggle_data(movies_df, 'budget_kaggle', 'budget_wiki')
fill_missing_kaggle_data(movies_df, 'revenue', 'box_office')
movies_df
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 6086    https://en.wikipedia.org/wiki/A_Fantastic_Woman  2018
# 6087    https://en.wikipedia.org/wiki/Permission_(film)  2018
# 6088      https://en.wikipedia.org/wiki/Loveless_(film)  2018
# 6089   https://en.wikipedia.org/wiki/Gemini_(2017_film)  2018
# 6090  https://en.wikipedia.org/wiki/How_to_Talk_to_G...  2018
#
#                                   imdb_link                       title_wiki  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1     https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2     https://www.imdb.com/title/tt0099005/                      Air America
# 3     https://www.imdb.com/title/tt0099012/                            Alice
# 4     https://www.imdb.com/title/tt0099018/                  Almost an Angel
# ...                                     ...                              ...
# 6086  https://www.imdb.com/title/tt5639354/                A Fantastic Woman
# 6087  https://www.imdb.com/title/tt5390066/                       Permission
# 6088  https://www.imdb.com/title/tt6304162/                         Loveless
# 6089  https://www.imdb.com/title/tt5795086/                           Gemini
# 6090  https://www.imdb.com/title/tt3859310/  How to Talk to Girls at Parties
#
#                                                Based on  \
# 0                           [Characters, by Rex Weiner]
# 1     [the novel, After Dark, My Sweet, by, Jim Thom...
# 2                [Air America, by, Christopher Robbins]
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6086                                                NaN
# 6087                                                NaN
# 6088                                                NaN
# 6089                                                NaN
# 6090  [", How to Talk to Girls at Parties, ", by, Ne...
#
#                                                Starring        Cinematography  \
# 0     [Andrew Dice Clay, Wayne Newton, Priscilla Pre...           Oliver Wood
# 1     [Jason Patric, Rachel Ward, Bruce Dern, George...          Mark Plummer
# 2     [Mel Gibson, Robert Downey Jr., Nancy Travis, ...         Roger Deakins
# 3     [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...        Carlo Di Palma
# 4           [Paul Hogan, Elias Koteas, Linda Kozlowski]          Russell Boyd
# ...                                                 ...                   ...
# 6086                    [Daniela Vega, Francisco Reyes]  Benjamín Echazarreta
# 6087  [Rebecca Hall, Dan Stevens, Morgan Spector, Fr...          Adam Bricker
# 6088  [Maryana Spivak, Aleksey Rozin, Matvey Novikov...      Mikhail Krichman
# 6089  [Lola Kirke, Zoë Kravitz, Greta Lee, Michelle ...           Andrew Reed
# 6090  [Elle Fanning, Alex Sharp, Nicole Kidman, Ruth...      Frank G. DeMarco
#
#                                            Release date  \
# 0                     [July 11, 1990, (, 1990-07-11, )]
# 1     [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2                   [August 10, 1990, (, 1990-08-10, )]
# 3                 [December 25, 1990, (, 1990-12-25, )]
# 4                                     December 19, 1990
# ...                                                 ...
# 6086  [12 February 2017, (, 2017-02-12, ), (, Berlin...
# 6087  [April 22, 2017, (, 2017-04-22, ), (, Tribeca ...
# 6088  [18 May 2017, (, 2017-05-18, ), (, Cannes, ), ...
# 6089  [March 12, 2017, (, 2017-03-12, ), (, SXSW, ),...
# 6090  [May 21, 2017, (, 2017-05-21, ), (, Cannes, ),...
#
#                                           Country        Language  ...  \
# 0                                   United States         English  ...
# 1                                   United States         English  ...
# 2                                   United States  [English, Lao]  ...
# 3                                   United States         English  ...
# 4                                              US         English  ...
# ...                                           ...             ...  ...
# 6086  [Chile, Germany, Spain, United States, [2]]         Spanish  ...
# 6087                                United States         English  ...
# 6088      [Russia, France, Belgium, Germany, [3]]         Russian  ...
# 6089                                United States         English  ...
# 6090              [United Kingdom, United States]         English  ...
#
#      release_date_kaggle              revenue              runtime  \
# 0             1990-07-11        20,423,389.00               104.00
# 1             1990-08-24         2,700,000.00               114.00
# 2             1990-08-10        33,461,269.00               112.00
# 3             1990-12-25         7,331,647.00               102.00
# 4             1990-12-21         6,939,946.00                95.00
# ...                  ...                  ...                  ...
# 6086          2017-04-06         3,700,000.00               104.00
# 6087          2017-04-22                  NaN                96.00
# 6088          2017-06-01         4,800,000.00               128.00
# 6089          2017-03-12           200,340.00                92.00
# 6090          2017-12-27           382,053.00               102.00
#
#                                        spoken_languages           status  \
# 0              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 1              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 2     [{'iso_639_1': 'en', 'name': 'English'}, {'iso...         Released
# 3              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 4              [{'iso_639_1': 'en', 'name': 'English'}]         Released
# ...                                                 ...              ...
# 6086           [{'iso_639_1': 'es', 'name': 'Español'}]         Released
# 6087           [{'iso_639_1': 'en', 'name': 'English'}]         Released
# 6088           [{'iso_639_1': 'ru', 'name': 'Pусский'}]         Released
# 6089           [{'iso_639_1': 'en', 'name': 'English'}]  Post Production
# 6090           [{'iso_639_1': 'en', 'name': 'English'}]         Released
#
#                                       tagline  \
# 0         Kojak. Columbo. Dirty Harry. Wimps.
# 1             All they risked was everything.
# 2     The few. The proud. The totally insane.
# 3                                         NaN
# 4                    Who does he think he is?
# ...                                       ...
# 6086                                      NaN
# 6087                                      NaN
# 6088                                      NaN
# 6089                                      NaN
# 6090        Some girls are out of this world.
#
#                          title_kaggle  video         vote_average  \
# 0     The Adventures of Ford Fairlane  False                 6.20
# 1                After Dark, My Sweet  False                 6.50
# 2                         Air America  False                 5.30
# 3                               Alice  False                 6.30
# 4                     Almost an Angel  False                 5.60
# ...                               ...    ...                  ...
# 6086                A Fantastic Woman  False                 7.20
# 6087                       Permission  False                 0.00
# 6088                         Loveless  False                 7.80
# 6089                           Gemini  False                 0.00
# 6090  How to Talk to Girls at Parties  False                 0.00
#
#                vote_count
# 0                   72.00
# 1                   17.00
# 2                  146.00
# 3                   57.00
# 4                   23.00
# ...                   ...
# 6086                13.00
# 6087                 1.00
# 6088                26.00
# 6089                 0.00
# 6090                10.00
#
# [6090 rows x 41 columns]

# %%
for col in movies_df.columns:
    lists_to_tuples = lambda x: tuple(x) if type(x) == list else x
    value_counts = movies_df[col].apply(lists_to_tuples).value_counts(dropna=False)
    num_values = len(value_counts)
    if num_values == 1:
        print(col)

movies_df['video'].value_counts(dropna=False)
# Out:
# video
# False    6090
# Name: video, dtype: int64

# %%
movies_df = movies_df.loc[:, ['imdb_id','id','title_kaggle','original_title','tagline','belongs_to_collection','url','imdb_link',
                       'runtime','budget_kaggle','revenue','release_date_kaggle','popularity','vote_average','vote_count',
                       'genres','original_language','overview','spoken_languages','Country',
                       'production_companies','production_countries','Distributor',
                       'Producer(s)','Director','Starring','Cinematography','Editor(s)','Writer(s)','Composer(s)','Based on'
                      ]]

movies_df.rename({'id':'kaggle_id',
                  'title_kaggle':'title',
                  'url':'wikipedia_url',
                  'budget_kaggle':'budget',
                  'release_date_kaggle':'release_date',
                  'Country':'country',
                  'Distributor':'distributor',
                  'Producer(s)':'producers',
                  'Director':'director',
                  'Starring':'starring',
                  'Cinematography':'cinematography',
                  'Editor(s)':'editors',
                  'Writer(s)':'writers',
                  'Composer(s)':'composers',
                  'Based on':'based_on'
                 }, axis='columns', inplace=True)

# %%
rating_counts = ratings.groupby(['movieId','rating'], as_index=False).count() \
                .rename({'userId':'count'}, axis=1) \
                .pivot(index='movieId',columns='rating', values='count')

# %%
movies_with_ratings_df = pd.merge(movies_df, rating_counts, left_on='kaggle_id', right_index=True, how='left')
movies_with_ratings_df[rating_counts.columns] = movies_with_ratings_df[rating_counts.columns].fillna(0)

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/movie_data"
engine = create_engine(db_string)

# %%
movies_df.to_sql(name='movies', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8240/489159978.py in <module>
# ----> 1 movies_df.to_sql(name='movies', con=engine)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1756             index_label=index_label,
#    1757             schema=schema,
# -> 1758             dtype=dtype,
#    1759         )
#    1760
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1648             dtype=dtype,
#    1649         )
# -> 1650         table.create()
#    1651         return table
#    1652
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in create(self)
#     856         if self.exists():
#     857             if self.if_exists == "fail":
# --> 858                 raise ValueError(f"Table '{self.name}' already exists.")
#     859             elif self.if_exists == "replace":
#     860                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'movies' already exists.

# %%
rows_imported = 0
start_time = time.time()
for data in pd.read_csv(f'{file_dir}ratings.csv', chunksize=1000000):
    print(f'importing rows {rows_imported} to {rows_imported + len(data)}...', end='')
    data.to_sql(name='ratings', con=engine, if_exists='append')
    rows_imported += len(data)

    # add elapsed time to final print out
    print(f'Done. {time.time() - start_time} total seconds elapsed')
# Out:
# importing rows 0 to 1000000...Done. 20.20317244529724 total seconds elapsed
# importing rows 1000000 to 2000000...Done. 40.79279065132141 total seconds elapsed
# importing rows 2000000 to 3000000...Done. 61.82847881317139 total seconds elapsed
# importing rows 3000000 to 4000000...Done. 82.06675386428833 total seconds elapsed
# importing rows 4000000 to 5000000...Done. 102.79420685768127 total seconds elapsed
# importing rows 5000000 to 6000000...Done. 123.0958514213562 total seconds elapsed
# importing rows 6000000 to 7000000...Done. 144.557368516922 total seconds elapsed
# importing rows 7000000 to 8000000...Done. 164.97819995880127 total seconds elapsed
# importing rows 8000000 to 9000000...Done. 185.333420753479 total seconds elapsed
# importing rows 9000000 to 10000000...Done. 205.9135708808899 total seconds elapsed
# importing rows 10000000 to 11000000...Done. 226.35932731628418 total seconds elapsed
# importing rows 11000000 to 12000000...Done. 246.45161652565002 total seconds elapsed
# importing rows 12000000 to 13000000...Done. 266.67208194732666 total seconds elapsed
# importing rows 13000000 to 14000000...Done. 287.3997600078583 total seconds elapsed
# importing rows 14000000 to 15000000...Done. 307.6793258190155 total seconds elapsed
# importing rows 15000000 to 16000000...Done. 327.3534197807312 total seconds elapsed
# importing rows 16000000 to 17000000...Done. 347.25032901763916 total seconds elapsed
# importing rows 17000000 to 18000000...Done. 366.8851718902588 total seconds elapsed
# importing rows 18000000 to 19000000...Done. 386.7570185661316 total seconds elapsed
# importing rows 19000000 to 20000000...Done. 406.8246695995331 total seconds elapsed
# importing rows 20000000 to 21000000...Done. 426.1934070587158 total seconds elapsed
# importing rows 21000000 to 22000000...Done. 445.8273186683655 total seconds elapsed
# importing rows 22000000 to 23000000...Done. 465.914186000824 total seconds elapsed
# importing rows 23000000 to 24000000...Done. 485.44807839393616 total seconds elapsed
# importing rows 24000000 to 25000000...Done. 504.8780632019043 total seconds elapsed
# importing rows 25000000 to 26000000...Done. 525.4040110111237 total seconds elapsed
# importing rows 26000000 to 26024289...Done. 525.8494074344635 total seconds elapsed
